# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Datasets/vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #Missing values

# %%
data.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  int64
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year  Genre Publisher  NA_Sales  \
# 0     1                Wii Sports      Wii  2006.0     10  Nintendo     41.49
# 1     2         Super Mario Bros.      NES  1985.0      4  Nintendo     29.08
# 2     3            Mario Kart Wii      Wii  2008.0      6  Nintendo     15.85
# 3     4         Wii Sports Resort      Wii  2009.0     10  Nintendo     15.75
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0      7  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00
# 4      8.89     10.22         1.00         31.37

# %%
data.nunique()
# Out:
# Rank            16291
# Name            11325
# Platform           31
# Year               39
# Genre              12
# Publisher         576
# NA_Sales          408
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      621
# dtype: int64

# %% [markdown]
# #Label encoding

# %%
for col in data.columns:
  if data[col].dtype=='object':
    print(col)
# Out:
# Name
# Platform
# Publisher

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
# all objects to transform
for col in data.columns:
  if data[col].dtype=='object':
    data[col] = encoder.fit_transform(data[col])

# %%
data.head()
# Out:
#    Rank   Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0     1  10849        26  2006.0     10        359     41.49     29.02
# 1     2   9201        11  1985.0      4        359     29.08      3.58
# 2     3   5493        26  2008.0      6        359     15.85     12.88
# 3     4  10851        26  2009.0     10        359     15.75     11.01
# 4     5   7247         5  1996.0      7        359     11.27      8.89
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
# 1      6.81         0.77         40.24
# 2      3.79         3.31         35.82
# 3      3.28         2.96         33.00
# 4     10.22         1.00         31.37

# %%
# to check what values are assigned to Genre field(column) after performing label encoding on it
data['Genre'] = encoder.fit_transform(data['Genre'])
encoded_to_original = dict(zip(encoder.transform(encoder.classes_),encoder.classes_))

for encoded_label,original_value in encoded_to_original.items():
  print(f'{encoded_label} - {original_value}')
# Out:
# 0 - Action
# 1 - Adventure
# 2 - Fighting
# 3 - Misc
# 4 - Platform
# 5 - Puzzle
# 6 - Racing
# 7 - Role-Playing
# 8 - Shooter
# 9 - Simulation
# 10 - Sports
# 11 - Strategy

# %%
encoder.inverse_transform(data['Genre'])
# Out:
# array(['989 Studios', '3DO', '505 Games', ..., '505 Games', '49Games',
#        '3DO'], dtype=object)

# %%
data.head()
# Out:
#    Rank   Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0     1  10849        26  2006.0     10        359     41.49     29.02
# 1     2   9201        11  1985.0      4        359     29.08      3.58
# 2     3   5493        26  2008.0      6        359     15.85     12.88
# 3     4  10851        26  2009.0     10        359     15.75     11.01
# 4     5   7247         5  1996.0      7        359     11.27      8.89
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
# 1      6.81         0.77         40.24
# 2      3.79         3.31         35.82
# 3      3.28         2.96         33.00
# 4     10.22         1.00         31.37

# %%
#run step all objects to transform

# %%
data.head()
# Out:
#    Rank   Name  Platform    Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0     1  10849        26  2006.0     10        359     41.49     29.02
# 1     2   9201        11  1985.0      4        359     29.08      3.58
# 2     3   5493        26  2008.0      6        359     15.85     12.88
# 3     4  10851        26  2009.0     10        359     15.75     11.01
# 4     5   7247         5  1996.0      7        359     11.27      8.89
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
# 1      6.81         0.77         40.24
# 2      3.79         3.31         35.82
# 3      3.28         2.96         33.00
# 4     10.22         1.00         31.37

# %%
data.corr()
# Out:
#                   Rank      Name  Platform      Year     Genre  Publisher  \
# Rank          1.000000 -0.013870 -0.085270  0.178027 -0.055518  -0.023116
# Name         -0.013870  1.000000  0.011886 -0.001269 -0.004255   0.026643
# Platform     -0.085270  0.011886  1.000000  0.167648  0.026665  -0.017938
# Year          0.178027 -0.001269  0.167648  1.000000 -0.125366   0.029802
# Genre        -0.055518 -0.004255  0.026665 -0.125366  1.000000  -0.051176
# Publisher    -0.023116  0.026643 -0.017938  0.029802 -0.051176   1.000000
# NA_Sales     -0.400315  0.012567  0.041976 -0.091285  0.018057   0.005370
# EU_Sales     -0.379137  0.006517  0.046748  0.006108  0.017005   0.013237
# JP_Sales     -0.269323  0.015869 -0.079621 -0.169387  0.030304   0.053019
# Other_Sales  -0.332735 -0.007089  0.054493  0.041128  0.009802   0.014569
# Global_Sales -0.426975  0.010973  0.027929 -0.074647  0.022215   0.019368
#
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
data.drop(columns=['Rank','Name','Platform','Year','Genre','Publisher'],inplace=True)

# %%
data.head()
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.corr()
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# NA_Sales      1.000000  0.768923  0.451283     0.634518      0.941269
# EU_Sales      0.768923  1.000000  0.436379     0.726256      0.903264
# JP_Sales      0.451283  0.436379  1.000000     0.290559      0.612774
# Other_Sales   0.634518  0.726256  0.290559     1.000000      0.747964
# Global_Sales  0.941269  0.903264  0.612774     0.747964      1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NA_Sales      16291 non-null  float64
#  1   EU_Sales      16291 non-null  float64
#  2   JP_Sales      16291 non-null  float64
#  3   Other_Sales   16291 non-null  float64
#  4   Global_Sales  16291 non-null  float64
# dtypes: float64(5)
# memory usage: 763.6 KB

# %% [markdown]
# #split the data

# %%
X = data.drop('Global_Sales',axis=1)
y = data['Global_Sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=25)

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_predict = reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,mean_absolute_percentage_error
import numpy as np

# %%
#Metrics in Linear Regression to evaluate the performance
linear_mse = mean_squared_error(y_test,linear_predict)
linear_r2 = r2_score(y_test,linear_predict)
linear_rmse = np.sqrt(linear_mse)
linear_mae = mean_absolute_error(y_test,linear_predict)
linear_mape = mean_absolute_percentage_error(y_test,linear_predict)
# linear_mape = np.mean(np.abs((y_test-linear_predict)/y_test))*100

# %% [markdown]
# #Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)

x_train_poly = poly.fit_transform(X_train)
poly_model = LinearRegression()
poly_model.fit(x_train_poly,y_train)

x_test_poly = poly.fit_transform(X_test)
poly_predict = poly_model.predict(x_test_poly)

# %%
#Metrics in Polynomial Regression to evaluate the performance
poly_mse = mean_squared_error(y_test,poly_predict)
poly_r2 = r2_score(y_test,poly_predict)
poly_rmse = np.sqrt(poly_mse)
poly_mae = mean_absolute_error(y_test,poly_predict)
poly_mape = mean_absolute_percentage_error(y_test,poly_predict)

# %% [markdown]
# #Lasso Regression(L1)

# %%
from sklearn.linear_model import Lasso
lasso_model = Lasso()

# %%
lasso_model.fit(X_train,y_train)
# Out:
# Lasso()

# %%
lasso_predict = lasso_model.predict(X_test)

# %%
#Metrics in Lasso Regression to evaluate the performance
lasso_mse = mean_squared_error(y_test,lasso_predict)
lasso_r2 = r2_score(y_test,lasso_predict)
lasso_rmse = np.sqrt(lasso_mse)
lasso_mae = mean_absolute_error(y_test,lasso_predict)
lasso_mape = mean_absolute_percentage_error(y_test,lasso_predict)

# %% [markdown]
# #Ridge Regression(L2)

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge()

# %%
ridge_model.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge_predict = ridge_model.predict(X_test)

# %%
#Metrics in Ridge Regression to evaluate the performance
ridge_mse = mean_squared_error(y_test,ridge_predict)
ridge_r2 = r2_score(y_test,ridge_predict)
ridge_rmse = np.sqrt(ridge_mse)
ridge_mae = mean_absolute_error(y_test,ridge_predict)
ridge_mape = mean_absolute_percentage_error(y_test,ridge_predict)

# %%
print('Linear Regression Metrics')
print('--------------------------')
print('MSE : ', linear_mse)
print('R2 : ', linear_r2)
print('RMSE : ', linear_rmse)
print('MAE : ', linear_mae)
print('MAPE : ', linear_mape)

print('\nPolynomial Regression Metrics')
print('--------------------------')
print('MSE : ', poly_mse)
print('R2 : ', poly_r2)
print('RMSE : ', poly_rmse)
print('MAE : ', poly_mae)
print('MAPE : ', poly_mape)

print('\nLasso Regression Metrics')
print('--------------------------')
print('MSE : ', lasso_mse)
print('R2 : ', lasso_r2)
print('RMSE : ', lasso_rmse)
print('MAE : ', lasso_mae)
print('MAPE : ', lasso_mape)

print('\nRidge Regression Metrics')
print('--------------------------')
print('MSE : ', ridge_mse)
print('R2 : ', ridge_r2)
print('RMSE : ', ridge_rmse)
print('MAE : ', ridge_mae)
print('MAPE : ', ridge_mape)
# Out:
# Linear Regression Metrics
# --------------------------
# MSE :  2.6743570800670982e-05
# R2 :  0.9999921948991463
# RMSE :  0.005171418644885655
# MAE :  0.002867819121875619
# MAPE :  0.028469976763113095
#
# Polynomial Regression Metrics
# --------------------------
# MSE :  2.734539861649979e-05
# R2 :  0.9999920192559296
# RMSE :  0.005229282801350467
# MAE :  0.0029431069616914925
# MAPE :  0.02935822806415755
#
# Lasso Regression Metrics
# --------------------------
# MSE :  2.945710427549582
# R2 :  0.14029554451109205
# RMSE :  1.7163072066356833
# MAE :  0.5931395553933244
# MAPE :  6.358677548440887
#
# Ridge Regression Metrics
# --------------------------
# MSE :  2.706245115237166e-05
# R2 :  0.9999921018340382
# RMSE :  0.005202158316734666
# MAE :  0.00294804718701821
# MAPE :  0.029248025739891576

# %%
linear_metrics = [linear_mse, linear_r2, linear_rmse, linear_mae, linear_mape]
poly_metrics = [poly_mse, poly_r2, poly_rmse, poly_mae, poly_mape]
lasso_metrics = [lasso_mse, lasso_r2, lasso_rmse, lasso_mae, lasso_mape]
ridge_metrics = [ridge_mse, ridge_r2, ridge_rmse, ridge_mae, ridge_mape]

index_metrics = ['MSE', 'R2', 'RMSE', 'MAE', 'MAPE']

data = {'Linear' : linear_metrics,
        'Polynomial' : poly_metrics,
        'Lasso' : lasso_metrics,
        'Ridge' : ridge_metrics}

df_metrics = pd.DataFrame(data, index=index_metrics)

df_metrics.index.name = 'Evaluation Metrics'
df_metrics.columns.name = 'Regression ML Models'

df_metrics
# Out:
# Regression ML Models    Linear  Polynomial     Lasso     Ridge
# Evaluation Metrics
# MSE                   0.000027    0.000027  2.945710  0.000027
# R2                    0.999992    0.999992  0.140296  0.999992
# RMSE                  0.005171    0.005229  1.716307  0.005202
# MAE                   0.002868    0.002943  0.593140  0.002948
# MAPE                  0.028470    0.029358  6.358678  0.029248

# %%
na_sales = float(input('Enter NA Sales : '))
eu_sales = float(input('Enter EU Sales : '))
jp_sales = float(input('Enter JP Sales : '))
other_sales = float(input('Enter other Sales : '))
# Out:
# Enter NA Sales : 42
# Enter EU Sales : 30
# Enter JP Sales : 4
# Enter other Sales : 9

# %%
input_data = np.array([[na_sales,eu_sales,jp_sales,other_sales]])
input_data
# Out:
# array([[42., 30.,  4.,  9.]])

# %%
#linear regression prediction
reg.predict(input_data)[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 84.9952891977555

# %%
#polynomial regression prediction
poly_model.predict(poly.transform(input_data))[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# 85.00288585313021

# %%
#lasso regression prediction
lasso_model.predict(input_data)[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# 6.701131307075245

# %%
#ridge regression prediction
ridge_model.predict(input_data)[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# 84.98807391810543
